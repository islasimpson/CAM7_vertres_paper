# %% [markdown]
# ### Plot composites of the QBO using 5S-5N averages.  Composite based on the transition from easteries to westerlies at 60hPa

# %% [markdown]
# ### Daily TEM diags computed at ./DATA_SORT/TEMdiags/day/ and then combined into monthly averages at ./DATA_SORT/TEMdiags/mon/

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from math import nan

from CASutils import averaging_utils as avg
from CASutils import qbo_utils as qbo
from CASutils import plotposition_utils as plotpos
from CASutils import readdata_utils as read
from CASutils import colorbar_utils as cbars

import sys

# %%
plotpath="/project/cas/islas/python_plots/CAM7_vertres_paper/FIGURES/"

# %% [markdown]
# ### Read in the monthly QBO composites, computed at ../DATA_SORT/QBOcomposites/monthly/

# %%
basepath="/project/cas/islas/python_savs/L83_paper/DATA_SORT/QBOcomposites/monthly/"
dz1000_comp = xr.open_dataset(basepath+'dz1000_composite_50hpa.nc')
dz900_comp = xr.open_dataset(basepath+'dz900_composite_50hpa.nc')
dz800_comp = xr.open_dataset(basepath+'dz800_composite_50hpa.nc')
dz700_comp = xr.open_dataset(basepath+'dz700_composite_50hpa.nc')
dz600_comp = xr.open_dataset(basepath+'dz600_composite_50hpa.nc')
dz500_comp = xr.open_dataset(basepath+'dz500_composite_50hpa.nc')
dz400_comp = xr.open_dataset(basepath+'dz400_composite_50hpa.nc')
era5_comp = xr.open_dataset(basepath+'ERA5_composite_50hpa.nc')

# %% [markdown]
# ### Plot the figure

# %%
import importlib
importlib.reload(qbo)
# Out:
# <module 'CASutils.qbo_utils' from '/home/islas/python/CASanalysis/CASutils/qbo_utils.py'>

# %%
fig = plt.figure(figsize=(16,16))

ax = qbo.plotqbowinds(fig, era5_comp.uzm, era5_comp.time, era5_comp.plev,2,-30,30,'ERA5, u',0.03,0.13,0.7,0.8,plevvar='plev', contourlines=True, contourlinescale=2, fsize=15)
ax.plot([-20,20],[-np.log10(80),-np.log10(80)], color='black')
ax = qbo.plotqbowinds(fig, dz1000_comp.uzm, dz1000_comp.time, dz1000_comp.ilev,2,-30,30,'dz1000, u',0.17,0.27,0.7,0.8, ylabel=False, contourlines=True, contourlinescale=2, fsize=15)
ax.plot([-20,20],[-np.log10(80),-np.log10(80)], color='black')
ax = qbo.plotqbowinds(fig, dz900_comp.uzm, dz900_comp.time, dz900_comp.ilev,2,-30,30,'dz900, u',0.29,0.39,0.7,0.8,ylabel=False, contourlines=True, contourlinescale=2, fsize=15)
ax.plot([-20,20],[-np.log10(80),-np.log10(80)], color='black')
ax = qbo.plotqbowinds(fig, dz800_comp.uzm, dz800_comp.time, dz800_comp.ilev,2,-30,30,'dz800, u',0.41,0.51,0.7,0.8,ylabel=False, contourlines=True, contourlinescale=2, fsize=15)
ax.plot([-20,20],[-np.log10(80),-np.log10(80)], color='black')
ax = qbo.plotqbowinds(fig, dz700_comp.uzm, dz700_comp.time, dz700_comp.ilev,2,-30,30,'dz700, u',0.53,0.63,0.7,0.8,ylabel=False, contourlines=True, contourlinescale=2, fsize=15)
ax.plot([-20,20],[-np.log10(80),-np.log10(80)], color='black')
ax = qbo.plotqbowinds(fig, dz600_comp.uzm, dz600_comp.time, dz600_comp.ilev,2,-30,30,'dz600, u',0.65,0.75,0.7,0.8,ylabel=False, contourlines=True, contourlinescale=2, fsize=15)
ax.plot([-20,20],[-np.log10(80),-np.log10(80)], color='black')
ax = qbo.plotqbowinds(fig, dz500_comp.uzm, dz500_comp.time, dz500_comp.ilev,2,-30,30,'dz500, u',0.77,0.87,0.7,0.8,ylabel=False, contourlines=True, contourlinescale=2, fsize=15)
ax.plot([-20,20],[-np.log10(80),-np.log10(80)], color='black')
ax = qbo.plotqbowinds(fig, dz400_comp.uzm, dz400_comp.time, dz400_comp.ilev,2,-30,30,'dz400, u',0.89,0.99,0.7,0.8,ylabel=False, contourlines=True, contourlinescale=2, fsize=15)
ax.plot([-20,20],[-np.log10(80),-np.log10(80)], color='black')
ax = cbars.plotcolorbar(fig, 2, -30, 30, 'u (ms$^{-1}$)',1,1.01,0.7,0.8,orient='vertical', contourlines=True, contourlinescale=2)


ciepfd = 0.025 ; cmaxepfd = 0.3
ax = qbo.plotqbowinds(fig, 86400.*era5_comp.utendepfd, era5_comp.time, era5_comp.plev, ciepfd, -1.*cmaxepfd, cmaxepfd, 
                      'ERA5, $\partial \overline{u}/\partial t_{\mathbf{\\nabla} \cdot \mathbf{F}}$',0.03,0.13,0.55,0.65,plevvar='plev', contourlines=True, contourlinescale=2,
                     fsize=15)
ax = qbo.plotqbowinds(fig, 86400.*dz1000_comp.utendepfd, dz1000_comp.time, dz1000_comp.ilev,ciepfd,-1*cmaxepfd,cmaxepfd,
                      'dz1000, $\partial \overline{u}/\partial t_{\mathbf{\\nabla} \cdot \mathbf{F}}$',0.17,0.27,0.55,0.65, ylabel=False, contourlines=True, contourlinescale=2,
                     fsize=15)
ax = qbo.plotqbowinds(fig, 86400.*dz900_comp.utendepfd, dz900_comp.time, dz900_comp.ilev,ciepfd,-1*cmaxepfd,cmaxepfd,
                      'dz900, $\partial \overline{u}/\partial t_{\mathbf{\\nabla} \cdot \mathbf{F}}$',0.29,0.39,0.55,0.65,ylabel=False, contourlines=True, contourlinescale=2,
                     fsize=15)
ax = qbo.plotqbowinds(fig, 86400.*dz800_comp.utendepfd, dz800_comp.time, dz800_comp.ilev,ciepfd,-1*cmaxepfd,cmaxepfd,
                      'dz800, $\partial \overline{u}/\partial t_{\mathbf{\\nabla} \cdot \mathbf{F}}$',0.41,0.51,0.55,0.65,ylabel=False, contourlines=True, contourlinescale=2,
                     fsize=15)
ax = qbo.plotqbowinds(fig, 86400.*dz700_comp.utendepfd, dz700_comp.time, dz700_comp.ilev,ciepfd,-1*cmaxepfd,cmaxepfd,
                      'dz700, $\partial \overline{u}/\partial t_{\mathbf{\\nabla} \cdot \mathbf{F}}$',0.53,0.63,0.55,0.65,ylabel=False, contourlines=True, contourlinescale=2,
                     fsize=15)
ax = qbo.plotqbowinds(fig, 86400.*dz600_comp.utendepfd, dz600_comp.time, dz600_comp.ilev,ciepfd,-1*cmaxepfd,cmaxepfd,
                      'dz600, $\partial \overline{u}/\partial t_{\mathbf{\\nabla} \cdot \mathbf{F}}$',0.65,0.75,0.55,0.65,ylabel=False, contourlines=True, contourlinescale=2,
                     fsize=15)
ax = qbo.plotqbowinds(fig, 86400.*dz500_comp.utendepfd, dz500_comp.time, dz500_comp.ilev,ciepfd,-1*cmaxepfd,cmaxepfd,
                      'dz500, $\partial \overline{u}/\partial t_{\mathbf{\\nabla} \cdot \mathbf{F}}$',0.77,0.87,0.55,0.65,ylabel=False, contourlines=True, contourlinescale=2,
                     fsize=15)
ax = qbo.plotqbowinds(fig, 86400.*dz400_comp.utendepfd, dz400_comp.time, dz400_comp.ilev,ciepfd,-1*cmaxepfd,cmaxepfd,
                      'dz400, $\partial \overline{u}/\partial t_{\mathbf{\\nabla} \cdot \mathbf{F}}$',0.89,0.99,0.55,0.65,ylabel=False, contourlines=True, contourlinescale=2,
                     fsize=15)
ax = cbars.plotcolorbar(fig, ciepfd, -1.*cmaxepfd, cmaxepfd, '$\partial \overline{u}/\partial t_{\mathbf{\\nabla} \cdot \mathbf{F}}$ (ms$^{-1}$day$^{-1}$)',1,1.01,0.55,0.65,orient='vertical',
                       contourlines=True, contourlinescale=2)

ax = qbo.plotqbowinds(fig, 86400.*(dz1000_comp.BUTGWSPEC + dz1000_comp.UTGWSPEC + dz1000_comp.UTGWORO),
                      dz1000_comp.time, dz1000_comp.ilev,ciepfd,-1.*cmaxepfd, cmaxepfd,'dz1000, GWD',0.17,0.27,0.4,0.5,ylabel=False,
                     contourlines=True, contourlinescale=2,fsize=15)
ax = qbo.plotqbowinds(fig, 86400.*(dz900_comp.BUTGWSPEC + dz900_comp.UTGWSPEC + dz900_comp.UTGWORO), 
                      dz900_comp.time, dz900_comp.ilev,ciepfd,-1*cmaxepfd,cmaxepfd,
                      'dz900, GWD',0.29,0.39,0.4,0.5,ylabel=False,
                     contourlines=True, contourlinescale=2,fsize=15)
ax = qbo.plotqbowinds(fig, 86400.*(dz800_comp.BUTGWSPEC + dz800_comp.UTGWSPEC + dz800_comp.UTGWORO), 
                      dz800_comp.time, dz800_comp.ilev,ciepfd,-1*cmaxepfd,cmaxepfd,
                      'dz800, GWD',0.41,0.51,0.4,0.5,ylabel=False,
                     contourlines=True, contourlinescale=2,fsize=15)
ax = qbo.plotqbowinds(fig, 86400.*(dz700_comp.BUTGWSPEC + dz700_comp.UTGWSPEC + dz700_comp.UTGWORO),
                      dz700_comp.time, dz700_comp.ilev,ciepfd,-1*cmaxepfd,cmaxepfd,
                      'dz700, GWD',0.53,0.63,0.4,0.5,ylabel=False,
                     contourlines=True, contourlinescale=2,fsize=15)
ax = qbo.plotqbowinds(fig, 86400.*(dz600_comp.BUTGWSPEC + dz600_comp.UTGWSPEC + dz600_comp.UTGWORO), 
                      dz600_comp.time, dz600_comp.ilev,ciepfd,-1*cmaxepfd,cmaxepfd,
                      'dz600, GWD',0.65,0.75,0.4,0.5,ylabel=False,
                     contourlines=True, contourlinescale=2,fsize=15)
ax = qbo.plotqbowinds(fig, 86400.*(dz500_comp.BUTGWSPEC + dz500_comp.UTGWSPEC + dz500_comp.UTGWORO), 
                      dz500_comp.time, dz500_comp.ilev,ciepfd,-1*cmaxepfd,cmaxepfd,
                      'dz500, GWD',0.77,0.87,0.4,0.5,ylabel=False,
                     contourlines=True, contourlinescale=2,fsize=15)
ax = qbo.plotqbowinds(fig, 86400.*(dz400_comp.BUTGWSPEC + dz400_comp.UTGWSPEC + dz400_comp.UTGWORO), 
                      dz400_comp.time, dz400_comp.ilev,ciepfd,-1*cmaxepfd,cmaxepfd,
                      'dz400, GWD',0.89,0.99,0.4,0.5,ylabel=False,
                     contourlines=True, contourlinescale=2,fsize=15)
ax = cbars.plotcolorbar(fig, ciepfd, -1.*cmaxepfd, cmaxepfd, 'GWD (ms$^{-1}$day$^{-1}$)',1,1.01,0.4,0.5,orient='vertical', contourlines=True)


clevs=[-4000,-3000,-2000,-1500,-1000,-750,-500,-250,-100,-50,0,
       50,100,250,500,750,1000,1500,2000,3000,4000]
levhilight=-750
hilightcolor='magenta'

ax = qbo.plotqbowinds(fig, era5_comp.epfz, era5_comp.time, era5_comp.plev, 0.1, -1., 1., 
                      'ERA5, $F_{z}$',0.03,0.13,0.25,0.35,plevvar='plev', speclevs=clevs, contourlines=True, contourlinescale=2,
                     xlabel='Lag (months)',fsize=15)    
#ax.contour(era5_comp.time, -1.*np.log10(era5_comp.plev), era5_comp.epfz.transpose("plev","time"), 
#           levels=[levhilight], colors=hilightcolor, linewidths=2)

ax = qbo.plotqbowinds(fig, dz1000_comp.epfz, dz1000_comp.time, dz1000_comp.ilev,0.1,-1.,1.,
                      'dz1000, $F_{z}$',0.17,0.27,0.25,0.35, ylabel=False, speclevs=clevs, contourlines=True, contourlinescale=2,
                     xlabel='Lag (months)',fsize=15)
#ax.contour(dz1000_comp.time, -1.*np.log10(dz1000_comp.ilev), dz1000_comp.epfz.transpose("ilev","time"), 
#           levels=[levhilight], colors=hilightcolor, linewidths=2)

ax = qbo.plotqbowinds(fig, dz900_comp.epfz, dz900_comp.time, dz900_comp.ilev,0.1,-1.,1.,
                      'dz900, $F_{z}$',0.29,0.39,0.25,0.35,ylabel=False, speclevs=clevs, contourlines=True, contourlinescale=2,
                     xlabel='Lag (months)',fsize=15)
#ax.contour(dz900_comp.time, -1.*np.log10(dz900_comp.ilev), dz900_comp.epfz.transpose("ilev","time"), 
#           levels=[levhilight], colors=hilightcolor, linewidths=2)

ax = qbo.plotqbowinds(fig, dz800_comp.epfz, dz800_comp.time, dz800_comp.ilev,0.1,-1.,1.,
                      'dz800, $F_{z}$',0.41,0.51,0.25,0.35,ylabel=False, speclevs=clevs, contourlines=True, contourlinescale=2,
                     xlabel='Lag (months)',fsize=15)
#ax.contour(dz800_comp.time, -1.*np.log10(dz800_comp.ilev), dz800_comp.epfz.transpose("ilev","time"), 
#           levels=[levhilight], colors=hilightcolor, linewidths=2)

ax = qbo.plotqbowinds(fig, dz700_comp.epfz, dz700_comp.time, dz700_comp.ilev,0.1,-1.,1.,
                      'dz700, $F_{z}$',0.53,0.63,0.25,0.35,ylabel=False, speclevs=clevs, contourlines=True, contourlinescale=2,
                     xlabel='Lag (months)',fsize=15)
#ax.contour(dz700_comp.time, -1.*np.log10(dz700_comp.ilev), dz700_comp.epfz.transpose("ilev","time"), 
#           levels=[levhilight], colors=hilightcolor, linewidths=2)

ax = qbo.plotqbowinds(fig, dz600_comp.epfz, dz600_comp.time, dz600_comp.ilev,0.1,-1.,1.,
                      'dz600, $F_{z}$',0.65,0.75,0.25,0.35,ylabel=False, speclevs=clevs, contourlines=True, contourlinescale=2,
                     xlabel='Lag (months)',fsize=15)
#ax.contour(dz600_comp.time, -1.*np.log10(dz600_comp.ilev), dz600_comp.epfz.transpose("ilev","time"), 
#           levels=[levhilight], colors=hilightcolor, linewidths=2)

ax = qbo.plotqbowinds(fig, dz500_comp.epfz, dz500_comp.time, dz500_comp.ilev,0.1,-1.,1.,
                      'dz500, $F_{z}$',0.77,0.87,0.25,0.35,ylabel=False, speclevs=clevs, contourlines=True, contourlinescale=2,
                     xlabel='Lag (months)',fsize=15)
#ax.contour(dz500_comp.time, -1.*np.log10(dz500_comp.ilev), dz500_comp.epfz.transpose("ilev","time"), 
#           levels=[levhilight], colors=hilightcolor, linewidths=2)

ax = qbo.plotqbowinds(fig, dz400_comp.epfz, dz400_comp.time, dz400_comp.ilev,0.1,-1.,1.,
                      'dz400, $F_{z}$',0.89,0.99,0.25,0.35,ylabel=False, speclevs=clevs, contourlines=True, contourlinescale=2,
                     xlabel='Lag (months)',fsize=15)
#ax.contour(dz400_comp.time, -1.*np.log10(dz400_comp.ilev), dz400_comp.epfz.transpose("ilev","time"), 
#           levels=[levhilight], colors=hilightcolor, linewidths=2)

ax = cbars.plotcolorbar_sayc(fig, clevs, '$F_{z}$ (m$^{3}$s$^{-2}$)',1,1.01,0.25,0.35,orient='vertical', contourlines=True,
                            ticks=[-4000,-2000,-1000,-500,-100,100,500,1000,2000,4000])

fig.savefig(plotpath+'fig2.pdf', bbox_inches='tight', facecolor='white')
