# %% [markdown]
# ### Plot composites of E-P flux convergence and vertical E-P flux for the period prior to the transition from easterlies to westerlies at each level. and the easterly/westerly decomposition at 50hPa.  Using 90 days prior to the transition from easterly to westerly zonal mean zonal wind

# %% [markdown]
# ### Daily TEM diags computed at ./DATA_SORT/TEMdiags/day/ and then combined into monthly averages at ./DATA_SORT/TEMdiags/mon/

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from math import nan

from CASutils import averaging_utils as avg
from CASutils import qbo_utils as qbo
from CASutils import plotposition_utils as plotpos
from CASutils import readdata_utils as read
from CASutils import colorbar_utils as cbars
from CASutils import filter_utils as filt
from CASutils import plothisto_utils as histo

import sys

# %%
plotpath="/project/cas/islas/python_plots/L83_paper/FIGURES/"

# %% [markdown]
# ### Composites of the transitions from easterly to westerly at each level using 30 day running means of zonal mean zonal wind

# %%
def maketransitioncomposites(dat, nlag):
    
    #---composite code
    def dothecomposite(dat, ewloc, nlag):
        #lagarr = np.arange(-nlag,nlag+1,1)
        lagarr = np.arange(-nlag,0)
        for icomp in np.arange(0,len(ewloc),1):
            #datuse = dat.isel(time=slice( int(ewloc[icomp]-nlag), int(ewloc[icomp]) + nlag + 1))
            datuse = dat.isel(time=slice( int(ewloc[icomp]-nlag),int(ewloc[icomp])))
            datuse['time'] = lagarr
            if (icomp == 0):
                datcomp = datuse / len(ewloc)
            else:
                datcomp = datcomp + datuse / len(ewloc)
        return datcomp
    #---end composite code
    
    comp_u = []
    comp_divf = [] 
    comp_fz = []
    
    for pplot in np.arange(0,dat.ilev.size,1):
        uzm = dat.uzm.isel(ilev=pplot)
        u30d = filt.runningmean(uzm, 30, dropna=False)
        ewloc = qbo.finde2w(u30d)
        ewloc = ewloc[ (ewloc > nlag) & (ewloc < (dat.time.size - nlag)) ]
        
        comp_u_t = dothecomposite(dat.uzm.isel(ilev=pplot), ewloc, nlag)
        comp_divf_t = dothecomposite(dat.utendepfd.isel(ilev=pplot), ewloc, nlag)
        comp_fz_t = dothecomposite(dat.epfz.isel(ilev=pplot), ewloc, nlag)
        
        comp_u_t = comp_u_t.rename('uzm')
        comp_divf_t = comp_divf_t.rename('divf')
        comp_fz_t = comp_fz_t.rename('fz')
        
        comp_u.append(comp_u_t)
        comp_divf.append(comp_divf_t)
        comp_fz.append(comp_fz_t)
        
        
    comp_u = xr.concat(comp_u, dim='ilev')
    comp_divf = xr.concat(comp_divf, dim='ilev')
    comp_fz = xr.concat(comp_fz, dim='ilev')
    
    comp_u['ilev'] = dat.ilev
    comp_divf['ilev'] = dat.ilev
    comp_fz['ilev'] = dat.ilev
    
    datout = xr.merge([comp_u, comp_divf, comp_fz])
    return datout

# %% [markdown]
# ### Composite divF and Fz at each level

# %%
nlags=90 # the number of days to composite over
w=5
era5 = xr.open_dataset("/project/cas/islas/python_savs/L83_paper/DATA_SORT/TEMdiags/day/ERA5.nc")
era5 = era5.rename(plev='ilev')
era5['ilev'] = era5.ilev/100.
era5 = era5.where( (era5.ilev < 110) & (era5.ilev > 7), drop=True)
era5_tr = avg.cosweightlat(era5, -1.*w, w)

era5_composite = maketransitioncomposites(era5_tr, nlags)

dz=['1000','900','800','700','600','500','400']
alldat=[]
for i in np.arange(0,len(dz),1):
    print(dz[i])
    basepath="/project/cas/islas/python_savs/L83_paper/DATA_SORT/TEMdiags/day/"
    dat = xr.open_dataset(basepath+'dz'+dz[i]+'_140km.nc')
    
    dat_tr = avg.cosweightlat(dat, -1*w, w)
    dat_tr = dat_tr.where((dat_tr.ilev < 110) & (dat_tr.ilev > 7), drop=True)
    
    datout = maketransitioncomposites(dat_tr, nlags)
    
    alldat.append(datout)
# Out:
# DatasetWeighted with weights along dimensions: lat
# 1000
# DatasetWeighted with weights along dimensions: lat
# 900
# DatasetWeighted with weights along dimensions: lat
# 800
# DatasetWeighted with weights along dimensions: lat
# 700
# DatasetWeighted with weights along dimensions: lat
# 600
# DatasetWeighted with weights along dimensions: lat
# 500
# DatasetWeighted with weights along dimensions: lat
# 400
# DatasetWeighted with weights along dimensions: lat

# %%
dz=['1000','900','800','700','600','500','400']
alldat_decomp=[]
basepath="/project/cas/islas/python_savs/L83_paper/DATA_SORT/QBOcomposites/90day_beforeW/"
for i in np.arange(0,len(dz),1):
    dat = xr.open_dataset(basepath+'QBOcomposite_dz'+str(dz[i])+'_90days_50.nc')
    dat = dat.mean('time')
    alldat_decomp.append(dat)
alldat_decomp = xr.concat(alldat_decomp, dim=dz)

era5_decomp = xr.open_dataset("/project/cas/islas/python_savs/L83_paper/DATA_SORT/QBOcomposites/90day_beforeW/QBOcomposite_ERA5_90days_50.nc")

# %%
fig = plt.figure(figsize=(16,16))


colors=['saddlebrown','teal','darkviolet','forestgreen','blue','red','goldenrod']

ax = fig.add_axes([0.05,0.32,0.25,0.32])
ax.set_ylim(-np.log10(100),-np.log10(10))
ax.set_yticks([-np.log10(100),-np.log10(70),-np.log10(50),-np.log10(30),-np.log10(20),-np.log10(10)])
ax.set_yticklabels(['100','70','50','30','20','10'], fontsize=14)
ax.set_ylabel('Pressure (hPa)', fontsize=14)
ax.set_xlim(-0.4,0.4)
ax.set_xticks([-0.4,-0.3,-0.2,-0.1,0,0.1,0.2,0.3,0.4])
ax.set_xticklabels(['-0.4','-0.3','-0.2','-0.1','0','0.1','0.2','0.3','0.4'], fontsize=14)
ax.set_xlabel(r'$\partial\overline{u}/\partial t_{\mathbf{\nabla}\cdot\mathbf{F}}$ (ms$^{-1}$day$^{-1}$)', fontsize=14)
ax.set_title(r'(a) $\partial\overline{u}/\partial t_{\mathbf{\nabla}\cdot\mathbf{F}}$, E-W transition', fontsize=16)
#ax.set_title('(a) $\\frac{\partial \overline{u}}{\partial t} _{\mathbf{\\nabla}}\cdot\mathbf{F}$, E-W transition', fontsize=16)

ax.plot([0,0],[-np.log10(100),-np.log10(10)], color='black')
ax.plot(86400.*era5_composite.divf.mean('time'),-1.*np.log10(era5_composite.ilev), color='black', linewidth=3, label='ERA5')
for i in np.arange(0,len(dz),1):
    dat = alldat[i]
    ax.plot(86400.*dat.divf.mean('time'),-1.*np.log10(dat.ilev), color=colors[i], linewidth=3, label='dz'+dz[i])

ax.legend(fontsize="14")
    
ax = fig.add_axes([0.38,0.32,0.25,0.32])
ax.set_ylim(-np.log10(100),-np.log10(10))
ax.set_yticks([-np.log10(100),-np.log10(70),-np.log10(50),-np.log10(30),-np.log10(20),-np.log10(10)])
ax.set_yticklabels(['100','70','50','30','20','10'], fontsize=14)
ax.set_ylabel('Pressure (hPa)', fontsize=14)
ax.set_xlim(-4000,1000)
ax.set_xticks([-4000,-3000,-2000,-1000,0,1000])
ax.set_xticklabels(['-4000','-3000','-2000','-1000','0','1000'], fontsize=14)
ax.set_xlabel('$F_{z}$ (m$^{3}$s$^{-2}$)', fontsize=14)
ax.set_title('(b) $F_{z}$, E-W transition', fontsize=16)

ax.plot([0,0],[-np.log10(100),-np.log10(10)], color='black')

ax.plot(era5_composite.fz.mean('time'),-1.*np.log10(era5_composite.ilev), color='black', linewidth=3)
for i in np.arange(0,len(dz),1):
    dat = alldat[i]
    ax.plot(dat.fz.mean('time'),-1.*np.log10(dat.ilev), color=colors[i], linewidth=3)

#---omitting this because it's in the plot above
#ax = fig.add_axes([0.05,0.05,0.16,0.2])
#ax.set_ylim(-2500,0)
#ax.set_yticks([-2500,-2000,-1500,-1000,-500,0])
#ax.set_xlim(-1,8)
#ax.set_xticks([-1,8])
#ax.set_xticklabels([' ',' '])
#ax.set_yticklabels(['-25','-20','-15','-10','-5','0'], fontsize=14)
#ax.set_ylabel('$\overrightarrow{F_{y}}$ ($\\times$10$^{2}$ m$^{2}$s$^{-2}$)', fontsize=14)
#for i in np.arange(0,len(dz),1):
#    ax = histo.oplotbar(ax, i, alldat_decomp.fz_all_50.sel(concat_dim=dz[i]), bottom=0, color=colors[i], label=dz[i])    
#ax = histo.oplotbar(ax, i+1, era5_decomp.fz_all_50, bottom=0, color='black', label='ERA5')
    
#ax = fig.add_axes([0.69,0.5,0.14,0.14])
#ax.set_ylim(-2700,0)
#ax.set_yticks([-2500,-2000,-1500,-1000,-500,0])
#ax.set_yticklabels(['-25','-20','-15','-10','-5','0'], fontsize=14)
#ax.set_ylabel('$\overrightarrow{F_{z}}$ ($\\times$10$^{2}$ m$^{2}$s$^{-2}$)', fontsize=14)
#ax.set_xlim(-1,8)
#ax.set_xticks([-1,8])
#ax.set_xticklabels([' ',' '])
#ax.set_title('(c) Eastward waves', fontsize=16)
#for i in np.arange(0,len(dz),1):
#    ax = histo.oplotbar(ax, i, alldat_decomp.fz_E_50.sel(concat_dim=dz[i]), bottom=0, color=colors[i], label=dz[i])
#ax = histo.oplotbar(ax, i+1, era5_decomp.fz_E_50, bottom=0, color='black', label='ERA5')

    
#ax = fig.add_axes([0.69,0.32,0.14,0.14])
#ax.set_ylim(-2700,0)
#ax.set_yticks([-2500,-2000,-1500,-1000,-500,0])
#ax.set_yticklabels(['-25','-20','-15','-10','-5','0'], fontsize=14)
#ax.set_ylabel('$\overrightarrow{F_{z}}$ ($\\times$10$^{2}$ m$^{2}$s$^{-2}$)', fontsize=14)
#ax.set_xlim(-1,8)
#ax.set_xticks([-1,8])
#ax.set_xticklabels([' ',' '])
#ax.set_title('(d) Westward waves', fontsize=16)
#for i in np.arange(0,len(dz),1):
#    ax = histo.oplotbar(ax, i, alldat_decomp.fz_W_50.sel(concat_dim=dz[i]), bottom=0, color=colors[i], label=dz[i])
#ax = histo.oplotbar(ax, i+1, era5_decomp.fz_W_50, bottom=0, color='black', label='ERA5')
    
    
fig.savefig(plotpath+'wavedriving_fz_composites.pdf', bbox_inches='tight', facecolor='white')

# %%
dz=['1000','900','800','700','600','500','400']
alldat_decomp=[]
basepath="/project/cas/islas/python_savs/L83_paper/DATA_SORT/QBOcomposites/90day_beforeW/"
for i in np.arange(0,len(dz),1):
    dat = xr.open_dataset(basepath+'QBOcomposite_dz'+str(dz[i])+'_90days_500_50hpaQBO.nc')
    dat = dat.mean('time')
    alldat_decomp.append(dat)
alldat_decomp = xr.concat(alldat_decomp, dim=dz)

era5_decomp = xr.open_dataset("/project/cas/islas/python_savs/L83_paper/DATA_SORT/QBOcomposites/90day_beforeW/QBOcomposite_ERA5_90days_500_50hpaQBO.nc")

# %%
fig = plt.figure(figsize=(16,16))

colors=['saddlebrown','teal','darkviolet','forestgreen','blue','red','goldenrod']

ax = fig.add_axes([0.69,0.5,0.14,0.14])
ax.set_ylim(-2700,0)
ax.set_yticks([-2500,-2000,-1500,-1000,-500,0])
ax.set_yticklabels(['-25','-20','-15','-10','-5','0'], fontsize=14)
ax.set_ylabel('$\overrightarrow{F_{z}}$ ($\\times$10$^{2}$ m$^{2}$s$^{-2}$)', fontsize=14)
ax.set_xlim(-1,8)
ax.set_xticks([-1,8])
ax.set_xticklabels([' ',' '])
ax.set_title('(c) Eastward waves', fontsize=16)
for i in np.arange(0,len(dz),1):
    ax = histo.oplotbar(ax, i, alldat_decomp.fz_E_500.sel(concat_dim=dz[i]), bottom=0, color=colors[i], label=dz[i])
ax = histo.oplotbar(ax, i+1, era5_decomp.fz_E_500, bottom=0, color='black', label='ERA5')

# %%
print(alldat_decomp.concat_dim)
# Out:
# <xarray.DataArray 'concat_dim' (concat_dim: 7)>
# array(['1000', '900', '800', '700', '600', '500', '400'], dtype='<U4')
# Coordinates:
#     zlon        float64 0.0
#     ilev        int64 500
#     pre         int32 500
#   * concat_dim  (concat_dim) <U4 '1000' '900' '800' '700' '600' '500' '400'

# %%
print(alldat_decomp.fz_E_500.sel(concat_dim='1000'))
# Out:
# <xarray.DataArray 'fz_E_500' ()>
# array(7617.15849046)
# Coordinates:
#     zlon        float64 0.0
#     ilev        int64 500
#     pre         int32 500
#     concat_dim  <U4 '1000'

# %%
dat = xr.open_dataset("/project/cas/islas/python_savs/L83_paper/DATA_SORT/E_W_waves_decomp/fluxes/fluxes_E_W_stat_dz1000_140km.nc")

# %%
dat = dat.sel(pre=50, method='nearest')

# %%
dat = avg.cosweightlat(dat, -5, 5)
# Out:
# DatasetWeighted with weights along dimensions: lat

# %%
plt.plot(dat.UWzm_W

# %%
print(dat)
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 6570)
# Coordinates:
#   * time       (time) object 1988-01-01 00:00:00 ... 2005-12-31 00:00:00
#     pre        int32 50
#     daystr     (time) object '01-01' '01-02' '01-03' ... '12-29' '12-30' '12-31'
# Data variables:
#     UVzm_E     (time) float64 0.0003659 5.462e-05 ... 0.0003641 5.157e-05
#     UVzm_W     (time) float64 0.0002895 7.629e-05 ... 0.0002876 7.49e-05
#     VTzm_E     (time) float64 0.0001113 -6.534e-05 ... 0.0001105 -6.61e-05
#     VTzm_W     (time) float64 0.0001154 -6.115e-05 ... 0.0001155 -6.23e-05
#     UWzm_E     (time) float64 -7.3e-08 -2.21e-07 ... -7.606e-08 -2.17e-07
#     UWzm_W     (time) float64 -6.128e-08 -2.52e-07 ... -6.396e-08 -2.494e-07
#     UVzm_stat  float64 0.003191
#     VTzm_stat  float64 -0.001456
#     UWzm_stat  float64 6.938e-06
