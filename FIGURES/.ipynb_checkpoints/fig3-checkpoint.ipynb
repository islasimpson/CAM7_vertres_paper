# %% [markdown]
# ### Plot the Dunkerton and Delisi QBO amplitude for the 140km top simulations

# %% [markdown]
# ### Daily TEM diags computed at ./DATA_SORT/TEMdiags/day/ and then combined into monthly averages at ./DATA_SORT/TEMdiags/mon/

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from math import nan

from CASutils import averaging_utils as avg
from CASutils import qbo_utils as qbo
from CASutils import plotposition_utils as plotpos
from CASutils import readdata_utils as read
from CASutils import colorbar_utils as cbars
from CASutils import filter_utils as filt
from CASutils import plothisto_utils as histo

import sys

# %%
plotpath="/project/cas/islas/python_plots/L83_paper/FIGURES/"

# %% [markdown]
# ## Dunkerton and Delisi QBO amplitude

# %%
# Read in the TEM diagnostics
dz1000_tem = xr.open_dataset("/project/cas/islas/python_savs/L83_paper/DATA_SORT/TEMdiags/mon/dz1000_140km.nc")
dz900_tem = xr.open_dataset("/project/cas/islas/python_savs/L83_paper/DATA_SORT/TEMdiags/mon/dz900_140km.nc")
dz800_tem = xr.open_dataset("/project/cas/islas/python_savs/L83_paper/DATA_SORT/TEMdiags/mon/dz800_140km.nc")
dz700_tem = xr.open_dataset("/project/cas/islas/python_savs/L83_paper/DATA_SORT/TEMdiags/mon/dz700_140km.nc")
dz600_tem = xr.open_dataset("/project/cas/islas/python_savs/L83_paper/DATA_SORT/TEMdiags/mon/dz600_140km.nc")
dz500_tem = xr.open_dataset("/project/cas/islas/python_savs/L83_paper/DATA_SORT/TEMdiags/mon/dz500_140km.nc")
dz400_tem = xr.open_dataset("/project/cas/islas/python_savs/L83_paper/DATA_SORT/TEMdiags/mon/dz400_140km.nc")
era5_tem = xr.open_dataset("/project/cas/islas/python_savs/L83_paper/DATA_SORT/TEMdiags/mon/ERA5.nc")

jra55_uzm = xr.open_mfdataset("/project/cas/islas/python_savs/L83_paper/RAW_DATA/JRA55/Uzm/Uzm*.nc")
monstr = xr.DataArray(jra55_uzm.indexes['time'].strftime('%Y%m'), coords=jra55_uzm.time.coords, name='monstr')
time = jra55_uzm.time.groupby(monstr).mean('time')
jra55_uzm = jra55_uzm.groupby(monstr).mean('time')
jra55_uzm = jra55_uzm.rename({'monstr':'time'})
jra55_uzm['time'] = time.values
#jra55_uzm = jra55_uzm.drop_vars('monstr')

merra2_uzm = xr.open_mfdataset("/project/cas/islas/python_savs/L83_paper/RAW_DATA/MERRA2/Uzm/Uzm*.nc")
monstr = xr.DataArray(merra2_uzm.indexes['time'].strftime('%Y%m'), coords=merra2_uzm.time.coords, name='monstr')
time = merra2_uzm.time.groupby(monstr).mean('time')
merra2_uzm = merra2_uzm.groupby(monstr).mean('time')
merra2_uzm = merra2_uzm.rename({'monstr':'time'})
merra2_uzm['time'] = time.values
#merra2_uzm = merra2_uzm.drop_vars('monstr')

dz1000_tem = dz1000_tem.isel(time=slice(12,dz1000_tem.time.size))
dz900_tem = dz900_tem.isel(time=slice(12,dz900_tem.time.size))
dz800_tem = dz800_tem.isel(time=slice(12,dz800_tem.time.size))
dz700_tem = dz700_tem.isel(time=slice(12,dz700_tem.time.size))
dz600_tem = dz600_tem.isel(time=slice(12,dz600_tem.time.size))
dz500_tem = dz500_tem.isel(time=slice(12,dz500_tem.time.size))
dz400_tem = dz400_tem.isel(time=slice(12,dz400_tem.time.size))
era5_tem = era5_tem.isel(time=slice(12,era5_tem.time.size))
merra2_uzm = merra2_uzm.isel(time=slice(12, merra2_uzm.time.size))
jra55_uzm = jra55_uzm.isel(time=slice(12, jra55_uzm.time.size))

### Sort some issues with 1987 missing in dz1000
dz1000_tem = dz1000_tem.sel(time=slice("1988-01-01","2005-12-31"))

# convert the pressure axis of era5 into hPa
era5_tem['plev'] = era5_tem.plev/100.

# Calculate the tropical average
dz1000_tem_tr = avg.cosweightlat(dz1000_tem.uzm,-5,5)
dz900_tem_tr = avg.cosweightlat(dz900_tem.uzm,-5,5)
dz800_tem_tr = avg.cosweightlat(dz800_tem.uzm,-5,5)
dz700_tem_tr = avg.cosweightlat(dz700_tem.uzm,-5,5)
dz600_tem_tr = avg.cosweightlat(dz600_tem.uzm,-5,5)
dz500_tem_tr = avg.cosweightlat(dz500_tem.uzm,-5,5)
dz400_tem_tr = avg.cosweightlat(dz400_tem.uzm,-5,5)
era5_tem_tr = avg.cosweightlat(era5_tem.uzm,-5,5)
jra55_uzm_tr = avg.cosweightlat(jra55_uzm.Uzm, -5, 5)
merra2_uzm_tr = avg.cosweightlat(merra2_uzm.Uzm, -5, 5)

# Deseasonalize
dz1000_tem_tr_deseas = dz1000_tem_tr.groupby('time.month') - dz1000_tem_tr.groupby('time.month').mean('time')
dz900_tem_tr_deseas = dz900_tem_tr.groupby('time.month') - dz900_tem_tr.groupby('time.month').mean('time')
dz800_tem_tr_deseas = dz800_tem_tr.groupby('time.month') - dz800_tem_tr.groupby('time.month').mean('time')
dz700_tem_tr_deseas = dz700_tem_tr.groupby('time.month') - dz700_tem_tr.groupby('time.month').mean('time')
dz600_tem_tr_deseas = dz600_tem_tr.groupby('time.month') - dz600_tem_tr.groupby('time.month').mean('time')
dz500_tem_tr_deseas = dz500_tem_tr.groupby('time.month') - dz500_tem_tr.groupby('time.month').mean('time')
dz400_tem_tr_deseas = dz400_tem_tr.groupby('time.month') - dz400_tem_tr.groupby('time.month').mean('time')
era5_tem_tr_deseas = era5_tem_tr.groupby('time.month') - era5_tem_tr.groupby('time.month').mean('time')
jra55_uzm_tr_deseas = jra55_uzm_tr.groupby('time.month') - jra55_uzm_tr.groupby('time.month').mean('time')
merra2_uzm_tr_deseas = merra2_uzm_tr.groupby('time.month') - merra2_uzm_tr.groupby('time.month').mean('time')

# Calculate the amplitude
dd_dz1000 = np.sqrt(2)*dz1000_tem_tr_deseas.std('time')
dd_dz900 = np.sqrt(2)*dz900_tem_tr_deseas.std('time')
dd_dz800 = np.sqrt(2)*dz800_tem_tr_deseas.std('time')
dd_dz700 = np.sqrt(2)*dz700_tem_tr_deseas.std('time')
dd_dz600 = np.sqrt(2)*dz600_tem_tr_deseas.std('time')
dd_dz500 = np.sqrt(2)*dz500_tem_tr_deseas.std('time')
dd_dz400 = np.sqrt(2)*dz400_tem_tr_deseas.std('time')
dd_era5 = np.sqrt(2)*era5_tem_tr_deseas.std('time')
dd_jra55 = np.sqrt(2)*jra55_uzm_tr_deseas.std('time').load()
dd_merra2 = np.sqrt(2)*merra2_uzm_tr_deseas.std('time').load()
# Out:
# DataArrayWeighted with weights along dimensions: lat
# DataArrayWeighted with weights along dimensions: lat
# DataArrayWeighted with weights along dimensions: lat
# DataArrayWeighted with weights along dimensions: lat
# DataArrayWeighted with weights along dimensions: lat
# DataArrayWeighted with weights along dimensions: lat
# DataArrayWeighted with weights along dimensions: lat
# DataArrayWeighted with weights along dimensions: lat
# DataArrayWeighted with weights along dimensions: lat
# DataArrayWeighted with weights along dimensions: lat
# /project/cas02/islas/miniconda3/envs/islaenv/lib/python3.10/site-packages/xarray/core/indexing.py:1593: PerformanceWarning: Slicing with an out-of-order index is generating 44 times more chunks
#   return self.array[key]
# /project/cas02/islas/miniconda3/envs/islaenv/lib/python3.10/site-packages/xarray/core/indexing.py:1593: PerformanceWarning: Slicing with an out-of-order index is generating 43 times more chunks
#   return self.array[key]

# %%
dd_jra55 = dd_jra55.load()
dd_merra2 = dd_merra2.load()

# %%
basepath="/project/cas/islas/python_savs/L83_paper/DATA_SORT/EWlengths/"
era5 = xr.open_dataset(basepath+"ERA5_20hPa.nc")
dz1000 = xr.open_dataset(basepath+"dz1000_140km_20hPa.nc")
dz900 = xr.open_dataset(basepath+"dz900_140km_20hPa.nc")
dz800 = xr.open_dataset(basepath+"dz800_140km_20hPa.nc")
dz700 = xr.open_dataset(basepath+"dz700_140km_20hPa.nc")
dz600 = xr.open_dataset(basepath+"dz600_140km_20hPa.nc")
dz500 = xr.open_dataset(basepath+"dz500_140km_20hPa.nc")
dz400 = xr.open_dataset(basepath+"dz400_140km_20hPa.nc")

# %%
plt.plot(jra55_uzm_tr_deseas.sel(pre=50, method='nearest'))
plt.plot(era5_tem_tr_deseas.sel(plev=50, method='nearest'))

# %%
plt.plot(dd_jra55.values, dd_jra55.pre)

# %%
fig = plt.figure(figsize=(16,16))

#---Dunkerton and Delisi amplitude
ax = fig.add_axes([0.0,0.7,0.5,0.3])
ax.set_ylim(-np.log10(100),-np.log10(10))
ax.set_yticks([-np.log10(100),-np.log10(70),-np.log10(50),-np.log10(30),-np.log10(20),-np.log10(10)])
ax.set_yticklabels(['100','70','50','30','20','10'], fontsize=14)
ax.set_ylabel('Pressure (hPa)', fontsize=14)
ax.set_xticks([0,5,10,15,20,25,30])
ax.set_xticklabels(['0','5','10','15','20','25','30'], fontsize=14)
ax.set_xlabel('$\sqrt{2}\sigma$ (ms$^{-1}$)', fontsize=14)
ax.set_title('QBO amplitude, 140km', fontsize=16)
ax.set_xlim(0,30)

ax.plot(dd_era5, -np.log10(dd_era5.plev), color='black', linewidth=3, label='ERA5')
ax.plot(dd_jra55, -np.log10(dd_jra55.pre), color='black', linewidth=3, linestyle='dashed', label='JRA55')
ax.plot(dd_merra2, -np.log10(dd_merra2.lev), color='black', linewidth=3, linestyle='dotted', label='MERRA2')
ax.plot(dd_dz1000, -np.log10(dd_dz1000.ilev), color='saddlebrown', linewidth=3, label='dz1000')
ax.plot(dd_dz900, -np.log10(dd_dz900.ilev), color='teal', linewidth=3, label='dz900')
ax.plot(dd_dz800, -np.log10(dd_dz800.ilev), color='darkviolet', linewidth=3, label='dz800')
ax.plot(dd_dz700, -np.log10(dd_dz700.ilev), color='forestgreen', linewidth=3, label='dz700')
ax.plot(dd_dz600, -np.log10(dd_dz600.ilev), color='blue', linewidth=3, label='dz600')
ax.plot(dd_dz500, -np.log10(dd_dz500.ilev), color='red', linewidth=3, label='dz500')
ax.plot(dd_dz400, -np.log10(dd_dz400.ilev), color='goldenrod', linewidth=3, label='dz400')

ax.plot([2,7],[-np.log10(100),-np.log10(100)], color='gray')
ax.plot([2,7],[-np.log10(70),-np.log10(70)], color='gray')
ax.plot([2,2],[-np.log10(100),-np.log10(70)], color='gray')
ax.plot([7,7],[-np.log10(100),-np.log10(70)], color='gray')

ax.plot([2,5.5],[-np.log10(70),-np.log10(37)], color='gray')
ax.plot([7,13.2],[-np.log10(70),-np.log10(37)], color='gray')

ax.legend()

ax = fig.add_axes([0.09,0.83,0.13,0.15])
ax.set_ylim(-np.log10(100),-np.log10(70))
ax.set_xlim(1.,7)
ax.set_yticks([-np.log10(100),-np.log10(90),-np.log10(80),-np.log10(70)])
ax.set_yticklabels(['100','90','80','70'])
ax.spines['bottom'].set_color('gray')
ax.spines['top'].set_color=('gray')
ax.spines['left'].set_color('gray')
ax.spines['right'].set_color('gray')
ax.set_xticks([])
ax.set_yticks([])

ax.plot(dd_era5, -np.log10(dd_era5.plev), color='black', linewidth=3, label='ERA5')
ax.plot(dd_jra55, -np.log10(dd_jra55.pre), color='black', linewidth=3, linestyle='dashed', label='JRA55')
ax.plot(dd_merra2, -np.log10(dd_merra2.lev), color='black', linewidth=3, linestyle='dotted', label='MERRA2')
ax.plot(dd_dz1000, -np.log10(dd_dz1000.ilev), color='saddlebrown', linewidth=3, label='dz1000')
ax.plot(dd_dz900, -np.log10(dd_dz900.ilev), color='teal', linewidth=3, label='dz900')
ax.plot(dd_dz800, -np.log10(dd_dz800.ilev), color='darkviolet', linewidth=3, label='dz800')
ax.plot(dd_dz700, -np.log10(dd_dz700.ilev), color='forestgreen', linewidth=3, label='dz700')
ax.plot(dd_dz600, -np.log10(dd_dz600.ilev), color='blue', linewidth=3, label='dz600')
ax.plot(dd_dz500, -np.log10(dd_dz500.ilev), color='red', linewidth=3, label='dz500')
ax.plot(dd_dz400, -np.log10(dd_dz400.ilev), color='goldenrod', linewidth=3, label='dz400')



#ax = fig.add_axes([0.57,0.7,0.5,0.3])
#ax.set_ylim(-100,1100)
#ax.set_xlim(0,32)
#ax.plot([0,32],[0,0], color='black')
#ax.set_yticks([0,200,400,600,800,1000])
#ax.set_yticklabels(['0','200','400','600','800','1000'], fontsize=14)
#ax.set_ylabel('Width (days)', fontsize=14)
#ax.set_title('(b) Length of QBO Westerly and Easterly phases', fontsize=16)
#ax.set_xticks([2,6,10,14,18,22,26,30])
#ax.set_xticklabels(['ERA5','dz1000','dz900','dz800','dz700','dz600','dz500','dz400'], fontsize=14)

# ax = histo.oplotbar(ax, 1, era5.Easterly.mean('ie'), color='royalblue', label='E')
# ax.plot(era5.Easterly*0 + 1, era5.Easterly, "o", markeredgecolor='lightsteelblue', markerfacecolor='None')
# ax = histo.oplotbar(ax, 2, era5.Westerly.mean('iw'), color='maroon', label='W')
# ax.plot(era5.Westerly*0 + 2, era5.Westerly, "o", markeredgecolor='lightsalmon', markerfacecolor='None')
# ax = histo.oplotbar(ax, 3, era5.Easterly.mean('ie') - era5.Westerly.mean('iw'), color='black', label='E$-$W')
# ax.plot([4,4],[-100,1100], color='black')

# ax = histo.oplotbar(ax, 5, dz1000.Easterly.mean('ie'), color='royalblue')
# ax.plot(dz1000.Easterly*0 + 5, dz1000.Easterly, "o", markeredgecolor='lightsteelblue', markerfacecolor='None')
# ax = histo.oplotbar(ax, 6, dz1000.Westerly.mean('iw'), color='maroon')
# ax.plot(dz1000.Westerly*0 + 6, dz1000.Westerly, "o", markeredgecolor='lightsalmon', markerfacecolor='None')
# ax = histo.oplotbar(ax, 7, dz1000.Easterly.mean('ie') - dz1000.Westerly.mean('iw'), color='black')
# ax.plot([8,8],[-100,1100], color='black')

# ax = histo.oplotbar(ax, 9, dz900.Easterly.mean('ie'), color='royalblue')
# ax.plot(dz900.Easterly*0 + 9, dz900.Easterly, "o", markeredgecolor='lightsteelblue', markerfacecolor='None')
# ax = histo.oplotbar(ax, 10, dz900.Westerly.mean('iw'), color='maroon')
# ax.plot(dz900.Westerly*0 + 10, dz900.Westerly, "o", markeredgecolor='lightsalmon', markerfacecolor='None')
# ax = histo.oplotbar(ax, 11, dz900.Easterly.mean('ie') - dz900.Westerly.mean('iw'), color='black')
# ax.plot([12,12],[-100,1100], color='black')

# ax = histo.oplotbar(ax, 13, dz800.Easterly.mean('ie'), color='royalblue')
# ax.plot(dz800.Easterly*0 + 13, dz800.Easterly, "o", markeredgecolor='lightsteelblue', markerfacecolor='None')
# ax = histo.oplotbar(ax, 14, dz800.Westerly.mean('iw'), color='maroon')
# ax.plot(dz800.Westerly*0 + 14, dz800.Westerly, "o", markeredgecolor='lightsalmon', markerfacecolor='None')
# ax = histo.oplotbar(ax, 15, dz800.Easterly.mean('ie') - dz800.Westerly.mean('iw'), color='black')
# ax.plot([16,16],[-100,1100], color='black')

# ax = histo.oplotbar(ax, 17, dz700.Easterly.mean('ie'), color='royalblue')
# ax.plot(dz700.Easterly*0 + 17, dz700.Easterly, "o", markeredgecolor='lightsteelblue', markerfacecolor='None')
# ax = histo.oplotbar(ax, 18, dz700.Westerly.mean('iw'), color='maroon')
# ax.plot(dz700.Westerly*0 + 18, dz700.Westerly, "o", markeredgecolor='lightsalmon', markerfacecolor='None')
# ax = histo.oplotbar(ax, 19, dz700.Easterly.mean('ie') - dz700.Westerly.mean('iw'), color='black')
# ax.plot([20,20],[-100,1100], color='black')

# ax = histo.oplotbar(ax, 21, dz600.Easterly.mean('ie'), color='royalblue')
# ax.plot(dz600.Easterly*0 + 21, dz600.Easterly, "o", markeredgecolor='lightsteelblue', markerfacecolor='None')
# ax = histo.oplotbar(ax, 22, dz600.Westerly.mean('iw'), color='maroon')
# ax.plot(dz600.Westerly*0 + 22, dz600.Westerly, "o", markeredgecolor='lightsalmon', markerfacecolor='None')
# ax = histo.oplotbar(ax, 23, dz600.Easterly.mean('ie') - dz600.Westerly.mean('iw'), color='black')
# ax.plot([24,24],[-100,1100], color='black')

# ax = histo.oplotbar(ax, 25, dz500.Easterly.mean('ie'), color='royalblue')
# ax.plot(dz500.Easterly*0 + 25, dz500.Easterly, "o", markeredgecolor='lightsteelblue', markerfacecolor='None')
# ax = histo.oplotbar(ax, 26, dz500.Westerly.mean('iw'), color='maroon')
# ax.plot(dz500.Westerly*0 + 26, dz500.Westerly, "o", markeredgecolor='lightsalmon', markerfacecolor='None')
# ax = histo.oplotbar(ax, 27, dz500.Easterly.mean('ie') - dz500.Westerly.mean('iw'), color='black')
# ax.plot([28,28],[-100,1100], color='black')

# ax = histo.oplotbar(ax, 29, dz400.Easterly.mean('ie'), color='royalblue')
# ax.plot(dz400.Easterly*0 + 29, dz400.Easterly, "o", markeredgecolor='lightsteelblue', markerfacecolor='None')
# ax = histo.oplotbar(ax, 30, dz400.Westerly.mean('iw'), color='maroon')
# ax.plot(dz400.Westerly*0 + 30, dz400.Westerly, "o", markeredgecolor='lightsalmon', markerfacecolor='None')
# ax = histo.oplotbar(ax, 31, dz400.Easterly.mean('ie') - dz400.Westerly.mean('iw'), color='black')

# ax.legend(loc='upper left')

fig.savefig(plotpath+'qboamplitude.pdf', bbox_inches='tight', facecolor='white')
