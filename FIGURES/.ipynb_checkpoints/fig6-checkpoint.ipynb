# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

from CASutils import qbo_utils as qbo
from CASutils import plotting_utils as myplots
from CASutils import colorbar_utils as cbars

# %%
plotpath="/project/cas/islas/python_plots/L83_paper/FIGURES/"

# %%
basepath="/project/cas/islas/python_savs/L83_paper/DATA_SORT/QBOcomposites/90day_beforeW_powerspec/"

# %%
era5_50 = xr.open_dataset(basepath+'ERA5_50hpa_5S5N_90days.nc')
dz1000_50 = xr.open_dataset(basepath+'dz1000_50hpa_5S5N.nc')
dz900_50 = xr.open_dataset(basepath+'dz900_50hpa_5S5N.nc')
dz800_50 = xr.open_dataset(basepath+'dz800_50hpa_5S5N.nc')
dz700_50 = xr.open_dataset(basepath+'dz700_50hpa_5S5N.nc')
dz600_50 = xr.open_dataset(basepath+'dz600_50hpa_5S5N.nc')
dz500_50 = xr.open_dataset(basepath+'dz500_50hpa_5S5N.nc')
dz400_50 = xr.open_dataset(basepath+'dz400_50hpa_5S5N.nc')

#era5_500 = xr.open_dataset(basepath+'ERA5_500hpa_5S5N_90days.nc')
#dz1000_500 = xr.open_dataset(basepath+'dz1000_500hpa_5S5N.nc')
#dz900_500 = xr.open_dataset(basepath+'dz900_500hpa_5S5N.nc')
#dz800_500 = xr.open_dataset(basepath+'dz800_500hpa_5S5N.nc')
#dz700_500 = xr.open_dataset(basepath+'dz700_500hpa_5S5N.nc')
#dz600_500 = xr.open_dataset(basepath+'dz600_500hpa_5S5N.nc')
#dz500_500 = xr.open_dataset(basepath+'dz500_500hpa_5S5N.nc')
#dz400_500 = xr.open_dataset(basepath+'dz400_500hpa_5S5N.nc')

#era5_200 = xr.open_dataset(basepath+'ERA5_200hpa_5S5N_90days.nc')
#dz1000_200 = xr.open_dataset(basepath+'dz1000_200hpa_5S5N.nc')
#dz900_200 = xr.open_dataset(basepath+'dz900_200hpa_5S5N.nc')
#dz800_200 = xr.open_dataset(basepath+'dz800_200hpa_5S5N.nc')
#dz700_200 = xr.open_dataset(basepath+'dz700_200hpa_5S5N.nc')
#dz600_200 = xr.open_dataset(basepath+'dz600_200hpa_5S5N.nc')
#dz500_200 = xr.open_dataset(basepath+'dz500_200hpa_5S5N.nc')
#dz400_200 = xr.open_dataset(basepath+'dz400_200hpa_5S5N.nc')

# %%
dcurves = xr.open_dataset("/project/cas/islas/python_savs/L83_paper/DATA_SORT/dispersion_curves/dispersion_curves.nc")

# %%
def oplot_dcurves(ax, dcurves, component='symmetric'):
    if (component == "symmetric"):
        for i in np.arange(0,dcurves.h_e.size,1):
            ax.plot(dcurves.k, dcurves.w_kelvin.isel(h_e=i), color='gray')
            ax.plot(dcurves.k, dcurves.w_ig_n1.isel(h_e=i), color='gray')
            ax.plot(dcurves.k, dcurves.w_etrap.isel(h_e=i), color='gray')
    else:
        for i in np.arange(0,dcurves.h_e.size,1):
            ax.plot(dcurves.k, dcurves.w_mrg.sel(h_e=i), color='gray')
            ax.plot(dcurves.k, dcurves.w_ig_nw.isel(h_e=i), color='gray')
    return ax

# %%
fig = plt.figure(figsize=(16,16))

ci=1e-6 ; cmax=-1e-5 ; cmin=-1e-5
component='symmetric'

#---non-linear contour interval for u'w'
cvals=[-0.0005,-0.00025,-0.0001,-0.00005,-0.000025,-0.00001,-0.000005,-0.0000025,
                0.0000025,0.000005,0.00001,0.000025,0.00005,0.0001,0.00025,0.0005]
cvals_cbar=[ i*10000 for i in cvals ]
ticks=[-5.0,-2.5,-1.0,-0.5,-0.25,-0.1,-0.05,-0.025,0.025,0.05,0.1,0.25,0.5,1.0,2.5,5.0]

xlim=14
ax = myplots.plotWK(fig, era5_50.cospec_uw.sel(component=component).mean('icomp'), era5_50.k, era5_50.w, ci, cmin, cmax,
                    '(a) ERA5',0,0.11,0.8,0.97,contourlinescale=2, cmap='blue2red', xlim=[-1*xlim, xlim],
                    speclevs=cvals)
ax = oplot_dcurves(ax, dcurves, component=component)

ax = myplots.plotWK(fig, dz1000_50.cospec_uw.sel(component=component).mean('icomp'), dz1000_50.k, dz1000_50.w, ci, -1.*cmax, cmax,
                    '(b) dz1000',0.13,0.24,0.8,0.97, ylabel=False, contourlinescale=2, cmap='blue2red', xlim=[-1*xlim, xlim],
                    speclevs=cvals)
ax = oplot_dcurves(ax, dcurves, component=component)


ax = myplots.plotWK(fig, dz900_50.cospec_uw.sel(component=component).mean('icomp'), dz900_50.k, dz900_50.w, ci, -1.*cmax, cmax,
                    '(c) dz900',0.25,0.36,0.8,0.97, ylabel=False, contourlinescale=2, cmap='blue2red', xlim=[-1*xlim, xlim],
                    speclevs=cvals)
ax = oplot_dcurves(ax, dcurves, component=component)

ax = myplots.plotWK(fig, dz800_50.cospec_uw.sel(component=component).mean('icomp'), dz800_50.k, dz800_50.w, ci, -1.*cmax, cmax,
                    '(d) dz800',0.37,0.48,0.8,0.97, ylabel=False, contourlinescale=2, cmap='blue2red', xlim=[-1*xlim, xlim],
                    speclevs=cvals)
ax = oplot_dcurves(ax, dcurves, component=component)

ax = myplots.plotWK(fig, dz700_50.cospec_uw.sel(component=component).mean('icomp'), dz700_50.k, dz700_50.w, ci, -1.*cmax, cmax,
                    '(e) dz700',0.49,0.6,0.8,0.97, ylabel=False, contourlinescale=2, cmap='blue2red', xlim=[-1*xlim, xlim],
                    speclevs=cvals)
ax = oplot_dcurves(ax, dcurves, component=component)

ax = myplots.plotWK(fig, dz600_50.cospec_uw.sel(component=component).mean('icomp'), dz600_50.k, dz600_50.w, ci, -1.*cmax, cmax,
                    '(f) dz600',0.61,0.72,0.8,0.97, ylabel=False, contourlinescale=2, cmap='blue2red', xlim=[-1*xlim, xlim],
                    speclevs=cvals)
ax = oplot_dcurves(ax, dcurves, component=component)

ax = myplots.plotWK(fig, dz500_50.cospec_uw.sel(component=component).mean('icomp'), dz500_50.k, dz500_50.w, ci, -1.*cmax, cmax,
                    '(g) dz500',0.73,0.84,0.8,0.97, ylabel=False, contourlinescale=2, cmap='blue2red', xlim=[-1*xlim, xlim],
                    speclevs=cvals)
ax = oplot_dcurves(ax, dcurves, component=component)

ax = myplots.plotWK(fig, dz400_50.cospec_uw.sel(component=component).mean('icomp'), dz400_50.k, dz400_50.w, ci, -1.*cmax, cmax,
                    '(h) dz400',0.85,0.96,0.8,0.97, ylabel=False, contourlinescale=2, cmap='blue2red', xlim=[-1*xlim, xlim],
                    speclevs=cvals)
ax = oplot_dcurves(ax, dcurves, component=component)

ax = cbars.plotcolorbar_sayc(fig, cvals_cbar,"$u'\omega$' ($\\times$10$^{-4}$ m Pa s$^{-2}$)",0.97,0.98,0.8,0.97,orient='vertical', ticks=ticks,
                            contourlines=True)

#----W power spectrum 50hPa
ci=0.2 ; cmin=-8.6 ; cmax=-7

ax = myplots.plotWK(fig, np.log10(era5_50.cospec_ww.sel(component=component).mean('icomp')), era5_50.k, era5_50.w, ci, cmin, cmax,
                    '(i) ERA5',0.,0.11,0.57,0.74,contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim],posonly=True)
ax = oplot_dcurves(ax, dcurves, component=component)

ax = myplots.plotWK(fig, np.log10(dz1000_50.cospec_ww.sel(component=component).mean('icomp')), dz1000_50.k, dz1000_50.w, ci, cmin, cmax,
                    '(j) dz1000',0.13,0.24,0.57,0.74,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)
ax = oplot_dcurves(ax, dcurves, component=component)

ax = myplots.plotWK(fig, np.log10(dz900_50.cospec_ww.sel(component=component).mean('icomp')), dz900_50.k, dz900_50.w, ci, cmin, cmax,
                    '(k) dz900',0.25,0.36,0.57,0.74,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)
ax = oplot_dcurves(ax, dcurves, component=component)

ax = myplots.plotWK(fig, np.log10(dz800_50.cospec_ww.sel(component=component).mean('icomp')), dz800_50.k, dz800_50.w, ci, cmin, cmax,
                    '(l) dz800',0.37,0.48,0.57,0.74,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)
ax = oplot_dcurves(ax, dcurves, component=component)

ax = myplots.plotWK(fig, np.log10(dz700_50.cospec_ww.sel(component=component).mean('icomp')), dz700_50.k, dz700_50.w, ci, cmin, cmax,
                    '(m) dz700',0.49,0.6,0.57,0.74,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)
ax = oplot_dcurves(ax, dcurves, component=component)

ax = myplots.plotWK(fig, np.log10(dz600_50.cospec_ww.sel(component=component).mean('icomp')), dz600_50.k, dz600_50.w, ci, cmin, cmax,
                    '(n) dz600',0.61,0.72,0.57,0.74,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)
ax = oplot_dcurves(ax, dcurves, component=component)

ax = myplots.plotWK(fig, np.log10(dz500_50.cospec_ww.sel(component=component).mean('icomp')), dz500_50.k, dz500_50.w, ci, cmin, cmax,
                    '(o) dz500',0.73,0.84,0.57,0.74,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)
ax = oplot_dcurves(ax, dcurves, component=component)

ax = myplots.plotWK(fig, np.log10(dz400_50.cospec_ww.sel(component=component).mean('icomp')), dz400_50.k, dz400_50.w, ci, cmin, cmax,
                    '(p) dz400',0.85,0.96,0.57,0.74,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)
ax = oplot_dcurves(ax, dcurves, component=component)

ax = cbars.plotcolorbar_log10(fig, ci, cmin, cmax,"$\omega$'$\omega$' (Pa$^{2}$s$^{-2}$)", 0.97,0.98,0.57,0.74,orient='vertical', contourlines=True,
                              posonly=True)

fig.savefig(plotpath+'cospectra_qbocomp.pdf', bbox_inches='tight', facecolor='white')

# %%
fig = plt.figure(figsize=(16,16))

ci=1e-6 ; cmax=-1e-5 ; cmin=-1e-5
component='symmetric'

#---non-linear contour interval for u'w'
cvals=[-0.0005,-0.00025,-0.0001,-0.00005,-0.000025,-0.00001,-0.000005,-0.0000025,
                0.0000025,0.000005,0.00001,0.000025,0.00005,0.0001,0.00025,0.0005]
cvals_cbar=[ i*10000 for i in cvals ]
ticks=[-5.0,-2.5,-1.0,-0.5,-0.25,-0.1,-0.05,-0.025,0.025,0.05,0.1,0.25,0.5,1.0,2.5,5.0]

xlim=14
ax = myplots.plotWK(fig, era5_50.cospec_uw.sel(component=component).mean('icomp'), era5_50.k, era5_50.w, ci, cmin, cmax,
                    '(a) ERA5',0,0.11,0.8,0.97,contourlinescale=2, cmap='blue2red', xlim=[-1*xlim, xlim],
                    speclevs=cvals)

ax = myplots.plotWK(fig, dz1000_50.cospec_uw.sel(component=component).mean('icomp') - era5_50.cospec_uw.sel(component=component).mean('icomp'), 
                    dz1000_50.k, dz1000_50.w, ci, -1.*cmax, cmax,
                    '(b) dz1000',0.13,0.24,0.8,0.97, ylabel=False, contourlinescale=2, cmap='blue2red', xlim=[-1*xlim, xlim],
                    speclevs=cvals)

#ax = myplots.plotWK(fig, dz900_50.cospec_uw.sel(component=component).mean('icomp'), dz900_50.k, dz900_50.w, ci, -1.*cmax, cmax,
#                    '(c) dz900',0.25,0.36,0.8,0.97, ylabel=False, contourlinescale=2, cmap='blue2red', xlim=[-1*xlim, xlim],
#                    speclevs=cvals)

#ax = myplots.plotWK(fig, dz800_50.cospec_uw.sel(component=component).mean('icomp'), dz800_50.k, dz800_50.w, ci, -1.*cmax, cmax,
#                    '(d) dz800',0.37,0.48,0.8,0.97, ylabel=False, contourlinescale=2, cmap='blue2red', xlim=[-1*xlim, xlim],
#                    speclevs=cvals)

#ax = myplots.plotWK(fig, dz700_50.cospec_uw.sel(component=component).mean('icomp'), dz700_50.k, dz700_50.w, ci, -1.*cmax, cmax,
#                    '(e) dz700',0.49,0.6,0.8,0.97, ylabel=False, contourlinescale=2, cmap='blue2red', xlim=[-1*xlim, xlim],
#                    speclevs=cvals)

#ax = myplots.plotWK(fig, dz600_50.cospec_uw.sel(component=component).mean('icomp'), dz600_50.k, dz600_50.w, ci, -1.*cmax, cmax,
#                    '(f) dz600',0.61,0.72,0.8,0.97, ylabel=False, contourlinescale=2, cmap='blue2red', xlim=[-1*xlim, xlim],
#                    speclevs=cvals)

ax = myplots.plotWK(fig, dz500_50.cospec_uw.sel(component=component).mean('icomp') - era5_50.cospec_uw.sel(component=component).mean('icomp'), 
                    dz500_50.k, dz500_50.w, ci, -1.*cmax, cmax,
                    '(g) dz500',0.73,0.84,0.8,0.97, ylabel=False, contourlinescale=2, cmap='blue2red', xlim=[-1*xlim, xlim],
                    speclevs=cvals)

ax = myplots.plotWK(fig, dz400_50.cospec_uw.sel(component=component).mean('icomp') - era5_50.cospec_uw.sel(component=component).mean('icomp'), 
                    dz400_50.k, dz400_50.w, ci, -1.*cmax, cmax,
                    '(h) dz400',0.85,0.96,0.8,0.97, ylabel=False, contourlinescale=2, cmap='blue2red', xlim=[-1*xlim, xlim],
                    speclevs=cvals)

# %%
fig = plt.figure(figsize=(16,16))

#----W power spectrum 50hPa
#ci=0.2 ; cmin=-8.6 ; cmax=-7
#ci=0.2 ; cmin=-10 ; cmax=-6
ci=0.1 ; cmin=-2 ; cmax=2

ax = myplots.plotWK(fig, np.log10(era5_50.cospec_ww.sel(component=component).mean('icomp')), era5_50.k, era5_50.w, ci, cmin, cmax,
                    '(i) ERA5',0.,0.11,0.57,0.74,contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim],posonly=True)

ax = myplots.plotWK(fig, np.log10(dz1000_50.cospec_ww.sel(component=component).mean('icomp')) - np.log10(era5_50.cospec_ww.sel(component=component).mean('icomp')), 
                    dz1000_50.k, dz1000_50.w, ci, cmin, cmax,
                    '(j) dz1000',0.13,0.24,0.57,0.74,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)

ax = myplots.plotWK(fig, np.log10(dz900_50.cospec_ww.sel(component=component).mean('icomp')) - np.log10(era5_50.cospec_ww.sel(component=component).mean('icomp')), 
                    dz900_50.k, dz900_50.w, ci, cmin, cmax,
                    '(k) dz900',0.25,0.36,0.57,0.74,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)

ax = myplots.plotWK(fig, np.log10(dz800_50.cospec_ww.sel(component=component).mean('icomp')) - np.log10(era5_50.cospec_ww.sel(component=component).mean('icomp')), 
                    dz800_50.k, dz800_50.w, ci, cmin, cmax,
                    '(l) dz800',0.37,0.48,0.57,0.74,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)

ax = myplots.plotWK(fig, np.log10(dz700_50.cospec_ww.sel(component=component).mean('icomp')) - np.log10(era5_50.cospec_ww.sel(component=component).mean('icomp')), 
                    dz700_50.k, dz700_50.w, ci, cmin, cmax,
                    '(m) dz700',0.49,0.6,0.57,0.74,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)

ax = myplots.plotWK(fig, np.log10(dz600_50.cospec_ww.sel(component=component).mean('icomp')) - np.log10(era5_50.cospec_ww.sel(component=component).mean('icomp')), 
                    dz600_50.k, dz600_50.w, ci, cmin, cmax,
                    '(n) dz600',0.61,0.72,0.57,0.74,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)

ax = myplots.plotWK(fig, np.log10(dz500_50.cospec_ww.sel(component=component).mean('icomp')) - np.log10(era5_50.cospec_ww.sel(component=component).mean('icomp')), 
                    dz500_50.k, dz500_50.w, ci, cmin, cmax,
                    '(o) dz500',0.73,0.84,0.57,0.74,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)

ax = myplots.plotWK(fig, np.log10(dz400_50.cospec_ww.sel(component=component).mean('icomp')) - np.log10(era5_50.cospec_ww.sel(component=component).mean('icomp')), 
                    dz400_50.k, dz400_50.w, ci, cmin, cmax,
                    '(p) dz400',0.85,0.96,0.57,0.74,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)

ax = cbars.plotcolorbar_log10(fig, ci, cmin, cmax,"$\omega$'$\omega$' (Pa$^{2}$s$^{-1}$)", 0.97,0.98,0.57,0.74,orient='vertical', contourlines=True,
                              posonly=True)

# %%
fig = plt.figure(figsize=(16,16))

#----W power spectrum 50hPa
ci=1e-9 ; cmin=-1e-8 ; cmax=1e-8
#ci=0.2 ; cmin=-10 ; cmax=-6
#ci=1e-10 ; cmin=-1e-9 ; cmax=1e-9

#ax = myplots.plotWK(fig, era5_50.cospec_ww.sel(component=component).mean('icomp'), era5_50.k, era5_50.w, ci, cmin, cmax,
#                    '(i) ERA5',0.,0.11,0.57,0.74,contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim],posonly=True)

ax = myplots.plotWK(fig, dz1000_50.cospec_ww.sel(component=component).mean('icomp') - era5_50.cospec_ww.sel(component=component).mean('icomp'), 
                    dz1000_50.k, dz1000_50.w, ci, cmin, cmax,
                    '(j) dz1000',0.13,0.24,0.57,0.74,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)

# %%
print((dz1000_50.cospec_ww.sel(component=component).mean('icomp') - era5_50.cospec_ww.sel(component=component).mean('icomp')).sel(k=10).values)
# Out:
# [-4.13160111e-11 -1.84840826e-09 -1.18413027e-09 -9.07688847e-10
#  -6.22953232e-10 -1.08013332e-10 -1.04159616e-09 -1.69269768e-09
#  -1.20291421e-09 -1.53649200e-09 -7.75860333e-10 -2.53634845e-09
#  -2.07402504e-09 -1.59650369e-09 -1.43563890e-09 -1.55251084e-09
#  -2.11903456e-09 -3.04158296e-09 -1.72191229e-09 -2.44446413e-09
#  -2.49356595e-09 -1.90634962e-09 -2.64950383e-09 -3.36605934e-09
#  -2.72694081e-09 -3.17921001e-09 -2.22293984e-09 -1.92630019e-10
#  -2.41545667e-09 -3.31513235e-09 -2.32664727e-09 -4.04358306e-09
#  -2.37152960e-09 -2.47673856e-09 -2.43263234e-09 -3.40066533e-09
#  -2.06569285e-09 -3.87177566e-09 -2.27362935e-09 -2.59707434e-09
#  -1.51689534e-09 -2.73442661e-09 -1.00017943e-09 -1.47398836e-09
#  -2.52828573e-09 -2.82189135e-09 -2.33095323e-09 -2.69030822e-09
#  -1.48886495e-09 -1.66590003e-09]

# %%
print(np.max(np.log10(dz1000_50.cospec_ww.sel(component=component).mean('icomp') - era5_50.cospec_ww.sel(component=component).mean('icomp'))))
# Out:
# <xarray.DataArray 'cospec_ww' ()>
# array(-8.37520431)
# Coordinates:
#     zlon       float64 ...
#     ilev       float64 ...
#     pre        int32 ...
#     component  <U13 'symmetric'
#     plev       float64 ...
#     level      float64 ...

# %%
print(np.max(dz1000_50.cospec_ww.sel(component=component).mean('icomp') - era5_50.cospec_ww.sel(component=component).mean('icomp')))
# Out:
# <xarray.DataArray 'cospec_ww' ()>
# array(4.21498165e-09)
# Coordinates:
#     zlon       float64 ...
#     ilev       float64 ...
#     pre        int32 ...
#     component  <U13 'symmetric'
#     plev       float64 ...
#     level      float64 ...

# %%
print(np.max(np.log10(dz1000_50.cospec_ww.sel(component=component).mean('icomp')) - np.log10(era5_50.cospec_ww.sel(component=component).mean('icomp'))))
# Out:
# <xarray.DataArray 'cospec_ww' ()>
# array(0.21149687)
# Coordinates:
#     zlon       float64 ...
#     ilev       float64 ...
#     pre        int32 ...
#     component  <U13 'symmetric'
#     plev       float64 ...
#     level      float64 ...

# %%
fig = plt.figure(figsize=(16,16))

ci=1e-6 ; cmax=-1e-5 ; cmin=-1e-5
component='antisymmetric'

#---non-linear contour interval for u'w'
cvals=[-0.0005,-0.00025,-0.0001,-0.00005,-0.000025,-0.00001,-0.000005,-0.0000025,
                0.0000025,0.000005,0.00001,0.000025,0.00005,0.0001,0.00025,0.0005]
cvals_cbar=[ i*10000 for i in cvals ]
ticks=[-5.0,-2.5,-1.0,-0.5,-0.25,-0.1,-0.05,-0.025,0.025,0.05,0.1,0.25,0.5,1.0,2.5,5.0]

xlim=14
ax = myplots.plotWK(fig, era5_50.cospec_uw.sel(component=component).mean('icomp'), era5_50.k, era5_50.w, ci, cmin, cmax,
                    '(a) ERA5',0,0.11,0.8,0.97,contourlinescale=2, cmap='blue2red', xlim=[-1*xlim, xlim],
                    speclevs=cvals)

ax = myplots.plotWK(fig, dz1000_50.cospec_uw.sel(component=component).mean('icomp'), dz1000_50.k, dz1000_50.w, ci, -1.*cmax, cmax,
                    '(b) dz1000',0.13,0.24,0.8,0.97, ylabel=False, contourlinescale=2, cmap='blue2red', xlim=[-1*xlim, xlim],
                    speclevs=cvals)

ax = myplots.plotWK(fig, dz900_50.cospec_uw.sel(component=component).mean('icomp'), dz900_50.k, dz900_50.w, ci, -1.*cmax, cmax,
                    '(c) dz900',0.25,0.36,0.8,0.97, ylabel=False, contourlinescale=2, cmap='blue2red', xlim=[-1*xlim, xlim],
                    speclevs=cvals)

ax = myplots.plotWK(fig, dz800_50.cospec_uw.sel(component=component).mean('icomp'), dz800_50.k, dz800_50.w, ci, -1.*cmax, cmax,
                    '(d) dz800',0.37,0.48,0.8,0.97, ylabel=False, contourlinescale=2, cmap='blue2red', xlim=[-1*xlim, xlim],
                    speclevs=cvals)

ax = myplots.plotWK(fig, dz700_50.cospec_uw.sel(component=component).mean('icomp'), dz700_50.k, dz700_50.w, ci, -1.*cmax, cmax,
                    '(e) dz700',0.49,0.6,0.8,0.97, ylabel=False, contourlinescale=2, cmap='blue2red', xlim=[-1*xlim, xlim],
                    speclevs=cvals)

ax = myplots.plotWK(fig, dz600_50.cospec_uw.sel(component=component).mean('icomp'), dz600_50.k, dz600_50.w, ci, -1.*cmax, cmax,
                    '(f) dz600',0.61,0.72,0.8,0.97, ylabel=False, contourlinescale=2, cmap='blue2red', xlim=[-1*xlim, xlim],
                    speclevs=cvals)

ax = myplots.plotWK(fig, dz500_50.cospec_uw.sel(component=component).mean('icomp'), dz500_50.k, dz500_50.w, ci, -1.*cmax, cmax,
                    '(g) dz500',0.73,0.84,0.8,0.97, ylabel=False, contourlinescale=2, cmap='blue2red', xlim=[-1*xlim, xlim],
                    speclevs=cvals)

ax = myplots.plotWK(fig, dz400_50.cospec_uw.sel(component=component).mean('icomp'), dz400_50.k, dz400_50.w, ci, -1.*cmax, cmax,
                    '(h) dz400',0.85,0.96,0.8,0.97, ylabel=False, contourlinescale=2, cmap='blue2red', xlim=[-1*xlim, xlim],
                    speclevs=cvals)

ax = cbars.plotcolorbar_sayc(fig, cvals_cbar,"$u'\omega$' ($\\times$10$^{-4}$ Pa$^{2}$s$^{-2}$)",0.97,0.98,0.8,0.97,orient='vertical', ticks=ticks,
                            contourlines=True)

#----W power spectrum 50hPa
ci=0.2 ; cmin=-8.6 ; cmax=-7

ax = myplots.plotWK(fig, np.log10(era5_50.cospec_ww.sel(component=component).mean('icomp')), era5_50.k, era5_50.w, ci, cmin, cmax,
                    '(i) ERA5',0.,0.11,0.57,0.74,contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim],posonly=True)

ax = myplots.plotWK(fig, np.log10(dz1000_50.cospec_ww.sel(component=component).mean('icomp')), dz1000_50.k, dz1000_50.w, ci, cmin, cmax,
                    '(j) dz1000',0.13,0.24,0.57,0.74,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)

ax = myplots.plotWK(fig, np.log10(dz900_50.cospec_ww.sel(component=component).mean('icomp')), dz900_50.k, dz900_50.w, ci, cmin, cmax,
                    '(k) dz900',0.25,0.36,0.57,0.74,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)

ax = myplots.plotWK(fig, np.log10(dz800_50.cospec_ww.sel(component=component).mean('icomp')), dz800_50.k, dz800_50.w, ci, cmin, cmax,
                    '(l) dz800',0.37,0.48,0.57,0.74,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)

ax = myplots.plotWK(fig, np.log10(dz700_50.cospec_ww.sel(component=component).mean('icomp')), dz700_50.k, dz700_50.w, ci, cmin, cmax,
                    '(m) dz700',0.49,0.6,0.57,0.74,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)

ax = myplots.plotWK(fig, np.log10(dz600_50.cospec_ww.sel(component=component).mean('icomp')), dz600_50.k, dz600_50.w, ci, cmin, cmax,
                    '(n) dz600',0.61,0.72,0.57,0.74,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)

ax = myplots.plotWK(fig, np.log10(dz500_50.cospec_ww.sel(component=component).mean('icomp')), dz500_50.k, dz500_50.w, ci, cmin, cmax,
                    '(o) dz500',0.73,0.84,0.57,0.74,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)

ax = myplots.plotWK(fig, np.log10(dz400_50.cospec_ww.sel(component=component).mean('icomp')), dz400_50.k, dz400_50.w, ci, cmin, cmax,
                    '(p) dz400',0.85,0.96,0.57,0.74,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)

ax = cbars.plotcolorbar_log10(fig, ci, cmin, cmax,"$\omega$'$\omega$' (Pa$^{2}$s$^{-1}$)", 0.97,0.98,0.57,0.74,orient='vertical', contourlines=True,
                              posonly=True)

# %%
fig = plt.figure(figsize=(16,16))

#----W power spectrum 500hPa
ci=0.1 ; cmin=-6 ; cmax=-5

ax = myplots.plotWK(fig, np.log10(era5_200.cospec_ww.sel(component=component).mean('icomp')), era5_200.k, era5_200.w, ci, cmin, cmax,
                    '(i) ERA5',0.,0.11,0.34,0.51,contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim],posonly=True)

ax = myplots.plotWK(fig, np.log10(dz1000_200.cospec_ww.sel(component=component).mean('icomp')), dz1000_200.k, dz1000_200.w, ci, cmin, cmax,
                    '(j) dz1000',0.13,0.24,0.34,0.51,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)

ax = myplots.plotWK(fig, np.log10(dz900_200.cospec_ww.sel(component=component).mean('icomp')), dz900_200.k, dz900_200.w, ci, cmin, cmax,
                    '(k) dz900',0.25,0.36,0.34,0.51,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)

ax = myplots.plotWK(fig, np.log10(dz800_200.cospec_ww.sel(component=component).mean('icomp')), dz800_200.k, dz800_200.w, ci, cmin, cmax,
                    '(l) dz800',0.37,0.48,0.34,0.51,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)

ax = myplots.plotWK(fig, np.log10(dz700_200.cospec_ww.sel(component=component).mean('icomp')), dz700_200.k, dz700_200.w, ci, cmin, cmax,
                    '(m) dz700',0.49,0.6,0.34,0.51,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)

ax = myplots.plotWK(fig, np.log10(dz600_200.cospec_ww.sel(component=component).mean('icomp')), dz600_200.k, dz600_200.w, ci, cmin, cmax,
                    '(n) dz600',0.61,0.72,0.34,0.51,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)

ax = myplots.plotWK(fig, np.log10(dz500_200.cospec_ww.sel(component=component).mean('icomp')), dz500_200.k, dz500_200.w, ci, cmin, cmax,
                    '(o) dz500',0.73,0.84,0.34,0.51,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)

ax = myplots.plotWK(fig, np.log10(dz400_200.cospec_ww.sel(component=component).mean('icomp')), dz400_200.k, dz400_200.w, ci, cmin, cmax,
                    '(p) dz400',0.85,0.96,0.34,0.51,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)

# %%
fig = plt.figure(figsize=(16,16))

ci=0.2 ; cmin=-8.6 ; cmax=-7

ax = myplots.plotWK(fig, np.log10(era5_50.cospec_ww.sel(component=component).mean('icomp')), era5_50.k, era5_50.w, ci, cmin, cmax,
                    '(i) ERA5',0.,0.11,0.57,0.74,contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim],posonly=True)

ax = myplots.plotWK(fig, np.log10(dz1000_50.cospec_ww.sel(component=component).mean('icomp')), dz1000_50.k, dz1000_50.w, ci, cmin, cmax,
                    '(j) dz1000',0.13,0.24,0.57,0.74,ylabel=False, contourlinescale=1, cmap='blue2red', xlim=[-1*xlim, xlim], posonly=True)
